# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import normalize
import scipy.cluster.hierarchy as shc
from sklearn.cluster import AgglomerativeClustering

# %%
df = pd.read_csv("/Users/mehuljangir/Downloads/credit-card.csv")
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df = df.dropna()
df_scaled = pd.DataFrame(normalize(df.iloc[:,1:]), columns=df.iloc[:,1:].columns)
df_scaled.head()
# Out:
#     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  0.039353           0.000787   0.091790          0.000000
# 1  0.293876           0.000083   0.000000          0.000000
# 2  0.310798           0.000125   0.096307          0.096307
# 3  0.504284           0.000617   0.009867          0.009867
# 4  0.428658           0.000237   0.315788          0.000000
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                0.091790       0.00000             0.000160
# 1                0.000000       0.59124             0.000000
# 2                0.000000       0.00000             0.000125
# 3                0.000000       0.00000             0.000051
# 4                0.315788       0.00000             0.000158
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.000080
# 1                    0.000000                          0.000000
# ...

# %%
plt.figure(figsize=(6, 4))
plt.title("Dendrograms")
dend = shc.dendrogram(shc.linkage(df_scaled, method='ward'))

# %%
plt.figure(figsize=(6, 4))
plt.title("Dendrograms")
dend = shc.dendrogram(shc.linkage(df_scaled, method='ward'))
plt.axhline(y=23, color='k', linestyle='--')

# %%
cluster = AgglomerativeClustering(n_clusters=3, affinity="euclidean", linkage="ward")
cluster.fit_predict(df_scaled)
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %%
plt.figure()
plt.scatter(df_scaled['BALANCE'], df_scaled['PURCHASES'], c = cluster.labels_, s=4)
